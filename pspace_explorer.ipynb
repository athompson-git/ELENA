# %% [markdown]
# # Exploring the parameter space for PBH formation
# ### Generic, quartic scalar potential
# $V(\phi, T) = D(T^2 - T_0^2) \phi^2 - (A T + C) \phi^3 + \frac{\lambda}{4} \phi^4$

# %% [markdown]
# ## Potential Params Corner Plot

# %%
from plotting import corner_plots_quartic_potential
json_filepath = "scans/pbh_scan_1MeV_debug.json"
corner_plots_quartic_potential(json_filepath, parameter_to_colorcode="f_pbh")

# %% [markdown]
# ## 2D distributions
